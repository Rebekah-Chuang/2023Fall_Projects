# %%
import numpy as np
import pandas as pd
import plotly.express as px
from scipy.stats import chi2_contingency, norm
from data_viz import *

# %%
data = pd.read_csv("data/animal_center.csv")
data
# Out:
#        animal_id     name animal_type     sex_intake    sex_outcome  \
# 0        A006100    Scamp         Dog  Neutered Male  Neutered Male
# 1        A006100    Scamp         Dog  Neutered Male  Neutered Male
# 2        A006100    Scamp         Dog  Neutered Male  Neutered Male
# 3        A047759     Oreo         Dog  Neutered Male  Neutered Male
# 4        A134067   Bandit         Dog  Neutered Male  Neutered Male
# ...          ...      ...         ...            ...            ...
# 157648   A894260    Sassy         Cat  Intact Female            NaN
# 157649   A894262  Diamond         Cat  Intact Female            NaN
# 157650   A894263     Ruby         Cat  Intact Female            NaN
# 157651   A894265    Gizmo         Cat    Intact Male            NaN
# 157652   A894266  Mittens         Cat  Intact Female            NaN
#
#                        breed         color date_of_birth  \
# 0       Spinone Italiano Mix  Yellow/White    2007-07-09
# 1       Spinone Italiano Mix  Yellow/White    2007-07-09
# 2       Spinone Italiano Mix  Yellow/White    2007-07-09
# 3                  Dachshund      Tricolor    2004-04-02
# 4          Shetland Sheepdog   Brown/White    1997-10-16
# ...                      ...           ...           ...
# 157648    Domestic Shorthair        Torbie           NaN
# 157649    Domestic Shorthair        Torbie           NaN
# 157650    Domestic Shorthair        Tortie           NaN
# 157651    Domestic Shorthair  Orange Tabby           NaN
# 157652    Domestic Shorthair    Blue/White           NaN
#
#                                        found_location      intake_datetime  \
# 0                        8700 Research in Austin (TX)  2014-03-07 14:26:00
# 1                   8700 Research Blvd in Austin (TX)  2014-12-19 10:21:00
# 2       Colony Creek And Hunters Trace in Austin (TX)  2017-12-07 14:07:00
# 3                                         Austin (TX)  2014-04-02 15:55:00
# 4                  12034 Research Blvd in Austin (TX)  2013-11-16 09:02:00
# ...                                               ...                  ...
# 157648                                    Austin (TX)  2023-12-05 16:56:00
# 157649                                    Austin (TX)  2023-12-05 16:56:00
# 157650                                    Austin (TX)  2023-12-05 16:56:00
# 157651                                    Austin (TX)  2023-12-05 16:56:00
# 157652                                    Austin (TX)  2023-12-05 16:56:00
#
#            outcome_datetime      intake_type intake_condition  \
# 0       2014-03-08 17:10:00    Public Assist           Normal
# 1       2014-12-20 16:35:00    Public Assist           Normal
# 2       2017-12-07 00:00:00            Stray           Normal
# 3       2014-04-07 15:12:00  Owner Surrender           Normal
# 4       2013-11-16 11:54:00    Public Assist          Injured
# ...                     ...              ...              ...
# 157648                  NaN  Owner Surrender           Normal
# 157649                  NaN  Owner Surrender           Normal
# 157650                  NaN  Owner Surrender           Normal
# 157651                  NaN  Owner Surrender           Normal
# 157652                  NaN  Owner Surrender           Normal
#
#            outcome_type outcome_subtype  age_upon_intake(years)  \
# 0       Return to Owner             NaN                     6.7
# 1       Return to Owner             NaN                     7.4
# 2       Return to Owner             NaN                    10.4
# 3              Transfer         Partner                    10.0
# 4       Return to Owner             NaN                    16.1
# ...                 ...             ...                     ...
# 157648              NaN             NaN                     NaN
# 157649              NaN             NaN                     NaN
# 157650              NaN             NaN                     NaN
# 157651              NaN             NaN                     NaN
# 157652              NaN             NaN                     NaN
#
#         age_upon_outcome(years)  duration(days)
# 0                           6.7             1.0
# 1                           7.4             1.0
# 2                          10.4            -1.0
# 3                          10.0             4.0
# 4                          16.1             0.0
# ...                         ...             ...
# 157648                      NaN             NaN
# 157649                      NaN             NaN
# 157650                      NaN             NaN
# 157651                      NaN             NaN
# 157652                      NaN             NaN
#
# [157653 rows x 18 columns]

# %% [markdown]
# # **Hypothesis1:**
# Is there a correlation between the neuter/spay rate of animals and their age?
#
# $H0$: There is no significant relationship between neuter/spay rate and age in animals.\
# $H1$: There is a significant relationship between neuter/spay rate and age in animals.

# %%
data.columns
# Out:
# Index(['animal_id', 'name', 'animal_type', 'sex_intake', 'sex_outcome',
#        'breed', 'color', 'date_of_birth', 'found_location', 'intake_datetime',
#        'outcome_datetime', 'intake_type', 'intake_condition', 'outcome_type',
#        'outcome_subtype', 'age_upon_intake(years)', 'age_upon_outcome(years)',
#        'duration(days)'],
#       dtype='object')

# %%
data.outcome_type.value_counts()
# Out:
# Adoption           73893
# Transfer           44908
# Return to Owner    24431
# Euthanasia          9965
# Died                1470
# Rto-Adopt           1079
# Disposal             767
# Missing               84
# Relocate              26
# Stolen                 5
# Name: outcome_type, dtype: int64

# %%
alive_outcome_type = ["Euthanasia", "Died", "Disposal", "Missing", "Stolen"]
sex_change = data[(data["animal_type"].isin(["Dog", "Cat"])) & 
                  (data["sex_intake"].isin(["Intact Female", "Intact Male"])) &
                  (~data["outcome_type"].isin(alive_outcome_type))]\
    [["animal_id", "animal_type", "sex_intake", "sex_outcome", "age_upon_outcome(years)", "outcome_datetime", "duration(days)", "outcome_type"]].reset_index(drop=True)
sex_change
# Out:
#       animal_id animal_type     sex_intake    sex_outcome  \
# 0       A163459         Dog  Intact Female  Intact Female
# 1       A191351         Cat  Intact Female  Intact Female
# 2       A212672         Dog  Intact Female  Intact Female
# 3       A256412         Dog    Intact Male    Intact Male
# 4       A309829         Dog    Intact Male    Intact Male
# ...         ...         ...            ...            ...
# 98300   A894260         Cat  Intact Female            NaN
# 98301   A894262         Cat  Intact Female            NaN
# 98302   A894263         Cat  Intact Female            NaN
# 98303   A894265         Cat    Intact Male            NaN
# 98304   A894266         Cat  Intact Female            NaN
#
#        age_upon_outcome(years)     outcome_datetime  duration(days)  \
# 0                         15.1  2014-11-14 19:28:00             0.0
# 1                         16.2  2015-11-17 13:29:00             3.0
# 2                         13.8  2013-12-06 14:34:00            10.0
# 3                         16.6  2013-10-06 14:26:00             0.0
# 4                         13.0  2014-11-12 15:34:00             2.0
# ...                        ...                  ...             ...
# 98300                      NaN                  NaN             NaN
# 98301                      NaN                  NaN             NaN
# 98302                      NaN                  NaN             NaN
# 98303                      NaN                  NaN             NaN
# 98304                      NaN                  NaN             NaN
#
#           outcome_type
# 0      Return to Owner
# 1      Return to Owner
# 2      Return to Owner
# 3      Return to Owner
# 4      Return to Owner
# ...                ...
# 98300              NaN
# 98301              NaN
# 98302              NaN
# 98303              NaN
# 98304              NaN
#
# [98305 rows x 8 columns]

# %%
sex_change["neutered_spayed_or_not"] = np.where(sex_change["sex_outcome"].isin(["Neutered Male", "Spayed Female"]), 1, 0)
sex_change
# Out:
#       animal_id animal_type     sex_intake    sex_outcome  \
# 0       A163459         Dog  Intact Female  Intact Female
# 1       A191351         Cat  Intact Female  Intact Female
# 2       A212672         Dog  Intact Female  Intact Female
# 3       A256412         Dog    Intact Male    Intact Male
# 4       A309829         Dog    Intact Male    Intact Male
# ...         ...         ...            ...            ...
# 98300   A894260         Cat  Intact Female            NaN
# 98301   A894262         Cat  Intact Female            NaN
# 98302   A894263         Cat  Intact Female            NaN
# 98303   A894265         Cat    Intact Male            NaN
# 98304   A894266         Cat  Intact Female            NaN
#
#        age_upon_outcome(years)     outcome_datetime  duration(days)  \
# 0                         15.1  2014-11-14 19:28:00             0.0
# 1                         16.2  2015-11-17 13:29:00             3.0
# 2                         13.8  2013-12-06 14:34:00            10.0
# 3                         16.6  2013-10-06 14:26:00             0.0
# 4                         13.0  2014-11-12 15:34:00             2.0
# ...                        ...                  ...             ...
# 98300                      NaN                  NaN             NaN
# 98301                      NaN                  NaN             NaN
# 98302                      NaN                  NaN             NaN
# 98303                      NaN                  NaN             NaN
# 98304                      NaN                  NaN             NaN
#
#           outcome_type  neutered_spayed_or_not
# 0      Return to Owner                       0
# 1      Return to Owner                       0
# 2      Return to Owner                       0
# 3      Return to Owner                       0
# 4      Return to Owner                       0
# ...                ...                     ...
# 98300              NaN                       0
# 98301              NaN                       0
# 98302              NaN                       0
# 98303              NaN                       0
# 98304              NaN                       0
#
# [98305 rows x 9 columns]

# %%
neutered_n_spayed_count = sex_change.neutered_spayed_or_not.sum()
animal_count = sex_change.animal_id.count()
neutered_n_spayed_pct = neutered_n_spayed_count/animal_count

print(f"{round(neutered_n_spayed_pct, 3)*100.0}% of the animals that were intact before have been neutered/spayed upon outcome.")
# Out:
# 63.5% of the animals that were intact before have been neutered/spayed upon outcome.

# %%
sex_change["age_group"] = pd.cut(sex_change["age_upon_outcome(years)"],
                                 bins=[-0.01, 2, 7, float('inf')],
                                 labels=["Young", "Adult", "Senior"])

sex_change
# Out:
#       animal_id animal_type     sex_intake    sex_outcome  \
# 0       A163459         Dog  Intact Female  Intact Female
# 1       A191351         Cat  Intact Female  Intact Female
# 2       A212672         Dog  Intact Female  Intact Female
# 3       A256412         Dog    Intact Male    Intact Male
# 4       A309829         Dog    Intact Male    Intact Male
# ...         ...         ...            ...            ...
# 98300   A894260         Cat  Intact Female            NaN
# 98301   A894262         Cat  Intact Female            NaN
# 98302   A894263         Cat  Intact Female            NaN
# 98303   A894265         Cat    Intact Male            NaN
# 98304   A894266         Cat  Intact Female            NaN
#
#        age_upon_outcome(years)     outcome_datetime  duration(days)  \
# 0                         15.1  2014-11-14 19:28:00             0.0
# 1                         16.2  2015-11-17 13:29:00             3.0
# 2                         13.8  2013-12-06 14:34:00            10.0
# 3                         16.6  2013-10-06 14:26:00             0.0
# 4                         13.0  2014-11-12 15:34:00             2.0
# ...                        ...                  ...             ...
# 98300                      NaN                  NaN             NaN
# 98301                      NaN                  NaN             NaN
# 98302                      NaN                  NaN             NaN
# 98303                      NaN                  NaN             NaN
# 98304                      NaN                  NaN             NaN
#
#           outcome_type  neutered_spayed_or_not age_group
# 0      Return to Owner                       0    Senior
# 1      Return to Owner                       0    Senior
# 2      Return to Owner                       0    Senior
# 3      Return to Owner                       0    Senior
# 4      Return to Owner                       0    Senior
# ...                ...                     ...       ...
# 98300              NaN                       0       NaN
# 98301              NaN                       0       NaN
# 98302              NaN                       0       NaN
# 98303              NaN                       0       NaN
# 98304              NaN                       0       NaN
#
# [98305 rows x 10 columns]

# %%
neuter_spay_age_contingency_table = pd.crosstab(sex_change["age_group"], sex_change["neutered_spayed_or_not"])
neuter_spay_age_contingency_table
# Out:
# neutered_spayed_or_not      0      1
# age_group
# Young                   29146  52577
# Adult                    4359   9120
# Senior                   1572    727

# %%
age_groups = ["Young", "Adult", "Senior"]

for age_group in age_groups:
    total = neuter_spay_age_contingency_table.loc[age_group].sum()
    neuter_spay_count = neuter_spay_age_contingency_table.loc[age_group, 1]
    neuter_spay_rate = round(neuter_spay_count/total, 4)*100.0
    print(f"The neuter/spay rate for {age_group.lower()} dogs/cats is {neuter_spay_rate}%")
# Out:
# The neuter/spay rate for young dogs/cats is 64.34%
# The neuter/spay rate for adult dogs/cats is 67.66%
# The neuter/spay rate for senior dogs/cats is 31.619999999999997%

# %%
chi2, p, dof, expected = chi2_contingency(neuter_spay_age_contingency_table)
print(f"chi2:    {chi2}")
print(f"p-value: {p}")
print(f"dof:     {dof}")
print(f"expected:\n{expected}")
# Out:
# chi2:    1128.7334319508877
# p-value: 7.918619626805163e-246
# dof:     2
# expected:
# [[29400.7002082  52322.2997918 ]
#  [ 4849.21060297  8629.78939703]
#  [  827.08918883  1471.91081117]]

# %%
chi2, p, dof, expected = chi2_contingency(neuter_spay_age_contingency_table)

# set significance level = 0.05
alpha = 0.05
if p < alpha:
    print("There is a significant relationship between age and neutered/spayed status.")
else:
    print("There is no significant relationship between age and neutered/spayed status.")
# Out:
# There is a significant relationship between age and neutered/spayed status.

# %%
fig = px.histogram(sex_change,
             x="age_group",
             color="neutered_spayed_or_not",
             barmode = "group",
             title="Neutered/Spayed Cases by Age Group")

fig.update_layout(title_x=0.5,
                  xaxis=dict(title="Age Group"),
                  yaxis=dict(title="Counts"),
                  legend_title_text="Neutered/Spayed Status",
                  height=600,
                  width=1000)

fig.update_layout(legend=dict(
    orientation="v",
    yanchor="bottom",
    y=1.02,
    xanchor="right",
    x=1))

fig.show()
